# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(np.random.normal(loc=0.0, scale=1.0, size=100) + np.random.randint(0.0, 1.0, size=100), bins=20)
# Out:
# <Axes: ylabel='Count'>
