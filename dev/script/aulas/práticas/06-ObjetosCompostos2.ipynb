# %%
# Listas com informações gênicas
simbolo = ['IFNG','Il10','Tnf','CSF2']
full_name = [
    'interferon gamma',
    'interleukin 10',
    'tumor necrosis factor',
    'colony stimulating factor 2'
]
source = ['HGNC:HGNC:5438','RGD:2886','MGI:MGI:104798','HGNC:HGNC:2434']
gene_type = ['protein coding','protein coding','protein coding','protein coding']
organism = ['Homo sapiens','Rattus norvegicus','Mus musculus','Homo sapiens']
chromosome = [12,13,17,5]

# %%
# Instanciar uma lista de listas com as informações genicas

# %%
# Instanciar um dicionário de listas com as informações genicas

# %%
# Indexar Símbolos no dicionário

# %%
# Indexar Cromossomo no dicionário

# %%
# Adicionar 'il6' à lista de símbolo

# %%
# Indexar Símbolos no dicionário

# %%
# Usar insert na posição  para inserir o IFNb
# Indexar Símbolos no dicionário

# %%
# Remover com remove o IFNb
# Indexar Símbolos no dicionário

# %%
# Usar pop na lista simbolo

# %%
import numpy as np

# %%
# Recuperar gene_matriz_lista

# %%
# Converter gene_matriz_lista para np.array

# %%
# Indexar gene_matriz_array[[0,2,-1]]

# %%
# Indexar gene_matriz_array[:,-1]

# %%
# Indexar gene_matriz_array[-1,:]

# %%
# Indexar gene_matriz_array[[0,1],[3,0]]

# %%
import pandas as pd

# %%
# Usar np.arange(4) para obter as colunas da df

# %%
gene_matriz = pd.DataFrame(
    columns=np.arange(4),
    data=[simbolo, full_name, source, gene_type, organism, chromosome],
    index=[
            'Símbolos',
            'Nomes completo',
            'Origem',
            'Tipo',
            'Organismo',
            'Cromossomo'
    ]
)
gene_matriz
# Out:
#                                0                  1                      2  \
# Símbolos                    IFNG               Il10                    Tnf
# Nomes completo  interferon gamma     interleukin 10  tumor necrosis factor
# Origem            HGNC:HGNC:5438           RGD:2886         MGI:MGI:104798
# Tipo              protein coding     protein coding         protein coding
# Organismo           Homo sapiens  Rattus norvegicus           Mus musculus
# Cromossomo                    12                 13                     17
#
#                                           3
# Símbolos                               CSF2
# Nomes completo  colony stimulating factor 2
# Origem                       HGNC:HGNC:2434
# Tipo                         protein coding
# Organismo                      Homo sapiens
# Cromossomo                                5

# %%
# Usar head

# %%
# Usar tail

# %%
# Usar describe

# %%
# Usar describe e df['column'].astype(dtype)

# %%
# df.dtypes

# %%
# .value_counts()

# %%
# Usar info

# %%
# Usar transpose na df

# %%
# Usar set_index('Símbolos', inplace=True) na df

# %%
# Converter gene_matriz_lista para uma df

# %%
# gene_matriz_lista.T

# %%
# set_index(0, inplace=True)

# %%
# Renomear as colunas para ['Nomes completo','Origem','Tipo','Organismo','Cromossomo']

# %%
# Instanciar um dicionário de listas com as informações genicas e .set_index('Símbolos')

# %%
# Indexar coluna 'Origem'

# %%
# Indexar colunas ['Origem', 'Tipo']

# %%
# Indexar colunas ['Tipo', 'Origem']

# %%
# Indexar IFNG com loc

# %%
# Indexar ['Tnf', 'IFNG'] com loc

# %%
# Indexar a primeira linha com iloc

# %%
# Indexar com iloc[[2,0]]

# %%
    # Indexar [['Tipo','Origem']].iloc[[2,0]]

# %%
# Indexar .iloc[:2]

# %%
# Filtrar com condicional > 10 em Cromossomo

# %%
# dir(gene_matriz_data)
