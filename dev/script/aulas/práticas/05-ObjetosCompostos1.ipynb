# %%
obj_tupla = (1,2,3,4,5,6)
obj_tupla
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
type(obj_tupla)
# Out:
# tuple

# %%
obj_lista = [1,2,3,4,5,6]
obj_lista
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
type(obj_lista)
# Out:
# list

# %%
obj_set = {1,2,3,4,5,6}
type(obj_set)
# Out:
# set

# %%
obj_dic = {'a': 1, 'b': 2, 'c': 3, 'd': 4}
obj_dic
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
type(obj_dic)
# Out:
# dict

# %%
print(obj_lista)
print(obj_dic)
# Out:
# [1, 2, 3, 4, 5, 6]
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
obj_tupla[1]
# Out:
# 2

# %%
obj_dic['d']
# Out:
# 4

# %%
obj_lista[3]
# Out:
# 4

# %%
obj_set
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
type(obj_dic['c'])
# Out:
# int

# %%
dir(obj_dic['c'])
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
# ...

# %%
obj_lista.append('Python')
obj_lista
# Out:
# [1, 2, 3, 4, 5, 6, 'Python']

# %%
obj_lista.pop()
obj_lista
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
obj_lista.pop(2)
obj_lista
# Out:
# [1, 2, 4, 5, 6]

# %%
obj_lista[2] = 40
obj_lista
# Out:
# [1, 2, 40, 5, 6]

# %%
obj_dic['a'] = 1.1
obj_dic
# Out:
# {'a': 1.1, 'b': 2, 'c': 3, 'd': 4}

# %%
del(obj_dic['b'])
obj_dic
# Out:
# {'a': 1.1, 'c': 3, 'd': 4}

# %%
print(obj_dic)
# Out:
# {'a': 1.1, 'c': 3, 'd': 4}

# %%
type(obj_dic)
# Out:
# dict

# %%
len(obj_lista)
# Out:
# 5

# %%
obj_lista
# Out:
# [1, 2, 40, 5, 6]

# %%
obj_lista[1:3]
# Out:
# [2, 40]

# %%
obj_lista[:3]
# Out:
# [1, 2, 40]

# %%
obj_lista[3:]
# Out:
# [5, 6]

# %%
obj_lista
# Out:
# [1, 2, 40, 5, 6]

# %%
1 in obj_lista
# Out:
# True

# %%
obj_lista[-1]
# Out:
# 6

# %%
obj_lista[:-2]
# Out:
# [1, 2, 40]

# %%
obj_lista[-3:]
# Out:
# [40, 5, 6]

# %%
a, b, *c = obj_lista

print(obj_lista)
print(a)
print(b)
print(c)
# Out:
# [1, 2, 40, 5, 6]
# 1
# 2
# [40, 5, 6]

# %%
obj_str = 'Python'
obj_str
# Out:
# 'Python'

# %%
obj_str[1]
# Out:
# 'y'

# %%
obj_str[2:5]
# Out:
# 'tho'

# %%
obj_dic.keys()
# Out:
# dict_keys(['a', 'c', 'd'])

# %%
obj_dic.items()
# Out:
# dict_items([('a', 1.1), ('c', 3), ('d', 4)])

# %%
type(obj_dic.items())
# Out:
# dict_items

# %%
obj_dic.items()
# Out:
# dict_items([('a', 1.1), ('c', 3), ('d', 4)])

# %%
obj_dic.values()
# Out:
# dict_values([1.1, 3, 4])

# %%
lista = [
    1,
    obj_dic,
    len(obj_lista),
    obj_tupla[2],
    obj_str[:2],
]
print(lista)
# Out:
# [1, {'a': 1.1, 'c': 3, 'd': 4}, 5, 3, 'Py']
