# %%
# Instanciar uma tupla de inteiros

# %%
# Usar função type na tupla

# %%
# Instanciar uma lista de inteiros

# %%
# Usar função type na tupla

# %%
# Instanciar um set de inteiros
# Verificar com type

# %%
# Instanciar um dicionario e verificar com type

# %%
# Usar print/display para comparar a lista com o dicionario

# %%
# Indexar para segundo valor da tupla

# %%
# Indexar chave 'd' no dicionario

# %%
# Indexar o 4 valor da lista

# %%
# Recuperar o set. Analisar a ausencia de indexação

# %%
# Verificar o tipo do objeto com chave 'c' no dicionario

# %%
# Verificar o dir() do objeto com chave 'c' no dicionario

# %%
# Usar append na lista

# %%
# Usar pop() e recuperar a lista

# %%
# Usar pop no valor 3 da lista recuperar lista

# %%
# Substituir o valor 3 da lista com lista = recebe

# %%
# Substituir o valor 'a' do dicionario com dicionario = recebe

# %%
# Deletar, usando del() o valor 'b' do dicionario

# %%
# Verificar o dicionario com print

# %%
# Usar len() na lista

# %%
# Recuperar a lista completa

# %%
# Indexar a lista na posição [1:3]

# %%
# Indexar a lista na posição [:3]

# %%
# Indexar a lista na posição [3:]

# %%
# Indexar a lista na posição [-1]

# %%
# Indexar a lista na posição [:-2]

# %%
# Indexar a lista na posição [-3:]

# %%
# Instanciar uma str

# %%
# Indexar a str na posição [1]

# %%
# Indexar a str na posição [2:5]

# %%
# Chamar as keys() do dicionario

# %%
# Chamar os items() do dicionario

# %%
# Chamar os values() do dicionario

# %%
# Instanciar uma lista com os objetos anteriores
# Lista heterogênea

# %%
# Somar, usando sum() os valores numéricos co dicionario.values()

# %%
# Instanciar um dicionario de strings e instanciar as str e o dicionario

# %%
# Verificar se uma estring está em uma lista usando o operador in
