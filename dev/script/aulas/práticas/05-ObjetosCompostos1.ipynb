# %%
tupla = ('1', 2, 3, 4, 5)
tupla
# Out:
# ('1', 2, 3, 4, 5)

# %%
type(tupla)
# Out:
# tuple

# %%
lista = [1, 2, 3, 4, 5]
lista
# Out:
# [1, 2, 3, 4, 5]

# %%
type(lista)
# Out:
# list

# %%
dicionario = {
    "a": 1,
    "b": 2,
    "c": 3
}
dicionario
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
print(tupla)
tupla[1]
# Out:
# ('1', 2, 3, 4, 5)
# 2

# %%
dicionario['d']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dicionario['d']
#
# KeyError: 'd'

# %%
dicionario['d'] = 4
dicionario
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
print(type(lista[4]))
print(lista[4])
# Out:
# <class 'int'>
# 5

# %%
lista
# Out:
# [1, 2, 3, 4, 5]

# %%
lista[1:3]
# Out:
# [2, 3]

# %%
help(dict)
# Out:
# Help on class dict in module builtins:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Built-in subclasses:
#  |      StgDict
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
# ...

# %%
display(tupla)
tupla = (1, 2, 3, 4, 5)
tupla = [1, 2, 3, 4, 5]
# Out:
# ('1', 2, 3, 4, 5)

# %%
tupla
# Out:
# ('1', 2, 3, 4, 5)

# %%
type(dicionario['a'])
# Out:
# int

# %%
dicionario.values()
# Out:
# dict_values([1, 2, 3, 4])

# %%
dicionario = {
    1: 'b',
    0: 'a',
}
dicionario
# Out:
# {1: 'b', 0: 'a'}

# %%
'a' in dicionario.('a')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 'a' in dicionario.key('a')
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
lista = [1, 2, 3, 4, 5]
print(f"Lista bacana: {lista}")
lista.append('6')
print(f"Lista bacana: {lista}")
# Out:
# Lista bacana: [1, 2, 3, 4, 5]
# Lista bacana: [1, 2, 3, 4, 5, '6']

# %%
lista
# Out:
# [1, 2, 3, 4, 5, '6']

# %%
dicionario['qualquer'] = "Abacaxi"
dicionario
# Out:
# {'a': 1, 'b': 2, 'c': 3, 1: False, 'qualquer': 'Abacaxi'}

# %%
lista = [1, 2, 3, 4, 5]
lista
# Out:
# [1, 2, 3, 4, 5]

# %%
num = lista.pop()
num = num + 1
lista.append(num)
print(num, lista)
# Out:
# 26 [1, 2, 3, 4, 26]

# %%
print(lista)
print(lista.pop(1))
# Out:
# [1, 2, 3, 4, 5]
# 2

# %%
lista
# Out:
# [1, 3, 4, 5]

# %%
lista.append(num)
print(f"{num} - {lista}")

# %%
lista
# Out:
# [1, 2, 3, 4]

# %%
lista = [1, 2, 3, 4, 5]
lista
# Out:
# [1, 2, 3, 4, 5]

# %%
novo_objeto_0 = lista[0]
novo_objeto_1 = lista[1]
novo_objeto_2 = lista[2]
novo_objeto_3 = lista[3]
novo_objeto_4 = lista[4]

print(novo_objeto_0,
novo_objeto_1,
novo_objeto_2,
novo_objeto_3,
novo_objeto_4)
# Out:
# 1 2 3 4 5

# %%
a, *b, e, cara = lista
print(a, b, e, cara)
# Out:
# 1 [2, 3] 4 5

# %%
# Out:
# 9
